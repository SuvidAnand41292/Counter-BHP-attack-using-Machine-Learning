# %%
#IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# GET THE DATA

# %%
DataFrame = pd.read_csv('OBS-Network-Data.csv')

# %%
#Quick Look at the Data Structure

# %%
DataFrame.describe()
# Out:
#              node   utilised BW Rate   packet drop rate  full bandwidth  \
# count  1075.000000        1075.000000       1075.000000     1075.000000
# mean      6.013953           0.597921          0.411362      540.465116
# std       3.001364           0.186569          0.183356      289.142068
# min       3.000000           0.235638          0.086126      100.000000
# 25%       3.000000           0.446906          0.247537      300.000000
# 50%       9.000000           0.577238          0.437988      500.000000
# 75%       9.000000           0.764550          0.556585      800.000000
# max       9.000000           0.928000          0.767939     1000.000000
#
#        avg delay time/sec  percentage of lost packet rate  \
# count         1075.000000                     1075.000000
# mean             0.000962                       41.161526
# std              0.000982                       18.352775
# min              0.000406                        8.610168
# 25%              0.000451                       24.748201
# 50%              0.000611                       43.796035
# 75%              0.000953                       56.667699
# max              0.005237                       76.791427
#
#        percentage of lost byte rate  packet received rate      used BW  \
# count                   1075.000000           1075.000000  1075.000000
# mean                      41.192107              0.588073   340.782202
# std                       18.377690              0.183779   232.136717
# min                        8.612629              0.232061    27.551250
# 25%                       24.753735              0.433279   138.408750
# 50%                       43.798804              0.562012   291.588750
# 75%                       56.672125              0.752463   515.182500
# max                       76.793887              0.913874   867.037500
#
#            lost BW  Packet size_byte  packet transmitted  packet received  \
# count  1075.000000            1075.0         1075.000000      1075.000000
# mean    199.682914            1440.0        48825.581395     30593.474419
# std     140.983649               0.0        26107.719833     20706.957909
# min      34.165000            1440.0         9048.000000      2451.000000
# 25%      81.197500            1440.0        27092.000000     12491.000000
# 50%     159.510000            1440.0        45188.000000     26847.000000
# 75%     279.272500            1440.0        72228.000000     46588.000000
# max     687.926250            1440.0        90324.000000     77131.000000
#
#        transmitted byte  received byte  10 run avg drop rate  10 run avg BW  \
# count      1.075000e+03   1.075000e+03           1075.000000    1075.000000
# mean       7.030884e+07   4.987343e+07              0.307604       0.553214
# std        3.759512e+07   7.697010e+07              0.138475       0.195448
# min        1.302912e+07   3.529440e+06              0.058749       0.207361
# 25%        3.901248e+07   1.773648e+07              0.189929       0.379870
# 50%        6.507072e+07   3.735792e+07              0.307019       0.508883
# 75%        1.040083e+08   6.708672e+07              0.405997       0.734102
# max        1.300666e+08   9.800666e+08              0.633714       0.890880
#
#        10 run delay  flood status
# count   1075.000000   1075.000000
# mean       0.000934      0.131936
# std        0.000536      0.145644
# min        0.000405      0.000000
# 25%        0.000656      0.023049
# 50%        0.000765      0.079331
# 75%        0.000984      0.230538
# max        0.004904      0.566739

# %%
DataFrame.head(5)
# Out:
#    node   utilised BW Rate   packet drop rate  full bandwidth  \
# 0      3           0.822038          0.190381            1000
# 1      9           0.275513          0.729111             100
# 2      3           0.923707          0.090383             900
# 3      9           0.368775          0.637710             100
# 4      3           0.905217          0.108670             800
#
#    avg delay time/sec  percentage of lost packet rate  \
# 0            0.004815                       19.031487
# 1            0.004815                       72.889036
# 2            0.000633                        9.035834
# 3            0.000552                       63.737843
# 4            0.000497                       10.864208
#
#    percentage of lost byte rate  packet received rate    used BW    lost BW  \
# 0                     19.038129              0.809619  822.03750  177.96250
# 1                     72.911141              0.270889   27.55125   72.44875
# 2                      9.038339              0.909617  831.33600   68.66400
# 3                     63.770999              0.362290   36.87750   63.12250
# 4                     10.866977              0.891330  724.17375   75.82625
#
#        ...        packet received  packet lost  transmitted byte  \
# 0      ...                  73128        17196         130066560
# 1      ...                   2451         6598          13029120
# 2      ...                  73930         7346         117037440
# 3      ...                   3278         5770          13029120
# 4      ...                  64379         7849         104008320
#
#   received byte  10 run avg drop rate  10 run avg BW  10 run delay  \
# 0     105304320              0.146594       0.780936      0.001838
# 1       3529440              0.517669       0.242451      0.002236
# 2     106459200              0.058749       0.886758      0.001751
# 3       4720320              0.522922       0.324522      0.001776
# 4      92705760              0.076069       0.869009      0.001767
#
#    node status  flood status          class
# 0            B      0.023455  'NB-No Block'
# 1           NB      0.460725          Block
# 2            B      0.000000     'No Block'
# 3           NB      0.439255          Block
# 4            B      0.000000     'No Block'
#
# [5 rows x 22 columns]

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075 entries, 0 to 1074
# Data columns (total 22 columns):
# node                              1075 non-null int64
# utilised BW Rate                  1075 non-null float64
# packet drop rate                  1075 non-null float64
# full bandwidth                    1075 non-null int64
# avg delay time/sec                1075 non-null float64
# percentage of lost packet rate    1075 non-null float64
# percentage of lost byte rate      1075 non-null float64
# packet received rate              1075 non-null float64
# used BW                           1075 non-null float64
# lost BW                           1075 non-null float64
# Packet size_byte                  1075 non-null int64
# packet transmitted                1075 non-null int64
# packet received                   1075 non-null int64
# packet lost                       1075 non-null object
# transmitted byte                  1075 non-null int64
# received byte                     1075 non-null int64
# 10 run avg drop rate              1075 non-null float64
# 10 run avg BW                     1075 non-null float64
# 10 run delay                      1075 non-null float64
# node status                       1075 non-null object
# flood status                      1075 non-null float64
# class                             1075 non-null object
# dtypes: float64(12), int64(7), object(3)
# memory usage: 184.8+ KB

# %%
# handling missing values
sns.heatmap(DataFrame.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
import matplotlib.pyplot as plt
DataFrame.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
DataFrame.columns
# Out:
# Index(['node ', 'utilised BW Rate ', 'packet drop rate', 'full bandwidth',
#        'avg delay time/sec', 'percentage of lost packet rate',
#        'percentage of lost byte rate', 'packet received rate', 'used BW',
#        'lost BW', 'Packet size_byte', 'packet transmitted', 'packet received',
#        'packet lost', 'transmitted byte', 'received byte',
#        '10 run avg drop rate', '10 run avg BW', '10 run delay', 'node status',
#        'flood status', 'class'],
#       dtype='object')

# %%
X = DataFrame.drop('class', axis = 1)
y = DataFrame['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(len(X_train), "train +", len(X_test), "test")
# Out:
# 720 train + 355 test

# %%
# DATA VISUALISATION

# %%
Y_train = pd.DataFrame(y_train.replace(to_replace=["'NB-No Block'", 'NB-Wait', "'No Block'", 'Block'], value=[0,1,2,3]))

# %%
# corelation

# %%
corr_matrix = X_train.corr()

# %%
corr_matrix["percentage of lost byte rate"].sort_values(ascending=False)
# Out:
# percentage of lost byte rate      1.000000
# percentage of lost packet rate    0.999985
# packet drop rate                  0.998530
# 10 run avg drop rate              0.981405
# flood status                      0.871849
# lost BW                           0.474128
# avg delay time/sec                0.222282
# 10 run delay                      0.016257
# node                             -0.120270
# full bandwidth                   -0.322936
# transmitted byte                 -0.322959
# packet transmitted               -0.322959
# received byte                    -0.449506
# packet received                  -0.678910
# used BW                          -0.700274
# 10 run avg BW                    -0.993259
# utilised BW Rate                 -0.998691
# packet received rate             -1.000000
# Packet size_byte                       NaN
# Name: percentage of lost byte rate, dtype: float64

# %%
sns.heatmap(X_train.corr(), linewidths=1)

# %%
sns.pairplot(X_train.drop(labels = ['Packet size_byte'], axis = 1))

# %%
sns.countplot(x='class',data=Y_train)

# %%
# DATA CLEANING

# %%
df_xtr = X_train.drop(labels = ['node ','percentage of lost packet rate', 'percentage of lost byte rate','packet received rate','Packet size_byte'], axis = 1)

# %%
# missing values
df_xtr['packet lost'] = pd.to_numeric(df_xtr['packet lost'], errors = 'coerce')

sns.heatmap(df_xtr.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# replacing missing values with mean value
df_xtr['packet lost'].fillna(value=df_xtr['packet lost'].mean(),inplace = True)

# %%
# changing categorical value with quantitative value
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_xtr['node status'] = encoder.fit_transform(df_xtr['node status'])

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_xtr)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# box plot
df_bp = df_xtr.copy()
df_bp['class'] = Y_train
for i in ['utilised BW Rate ', 'packet drop rate', 'full bandwidth',
       'avg delay time/sec', 'used BW', 'lost BW', 'packet transmitted',
       'packet received', 'packet lost', 'transmitted byte', 'received byte',
       '10 run avg drop rate', '10 run avg BW', '10 run delay', 'node status',
       'flood status',]:
    plt.figure(figsize=(6,6))

    sns.boxplot(x='class' , y= i , data = df_bp, palette='winter')

# %%
#handling outliers
df_xtr.drop(['avg delay time/sec', '10 run delay','flood status' ], axis = 1, inplace = True)

# %%
#TRAINING MODEL

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
clf_1 = logmodel.fit(df_xtr,y_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
#K-Fold CROSS VALIDATION logestic regression

from sklearn.model_selection import cross_val_score
scores_1 = cross_val_score(clf_1, df_xtr, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_1.mean(), scores_1.std() * 2))
# Out:
# Accuracy: 0.68 (+/- 0.09)

# %%
# random forest 
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
clf_2 = rfc.fit(df_xtr, y_train)

# %%
#K-Fold CROSS VALIDATION random forest

scores_2 = cross_val_score(clf_2, df_xtr, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_2.mean(), scores_2.std() * 2))
# Out:
# Accuracy: 0.98 (+/- 0.03)

# %%
#LDA & QDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
qda = QuadraticDiscriminantAnalysis()
lda = LinearDiscriminantAnalysis() 
clf_3 = lda.fit(df_xtr, y_train)
clf_4 = qda.fit(df_xtr, y_train)
# Out:
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
#K-Fold CROSS VALIDATION lda

scores_3 = cross_val_score(clf_3, df_xtr, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_3.mean(), scores_3.std() * 2))
# Out:
# Accuracy: 0.68 (+/- 0.09)
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
#K-Fold CROSS VALIDATION qda

scores_4 = cross_val_score(clf_4, df_xtr, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_4.mean(), scores_4.std() * 2))
# Out:
# Accuracy: 0.14 (+/- 0.01)
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])

# %%
#TEST SET PERFORMANCE

# %%
df_xtst = X_test.drop(labels = ['node ','percentage of lost packet rate', 'percentage of lost byte rate',
                                'packet received rate','Packet size_byte','avg delay time/sec', 
                                '10 run delay','flood status'], axis = 1)

df_xtst['packet lost'] = pd.to_numeric(df_xtst['packet lost'], errors = 'coerce')
df_xtst['packet lost'].fillna(value=df_xtst['packet lost'].mean(),inplace = True)

encoder = LabelEncoder()
df_xtst['node status'] = encoder.fit_transform(df_xtst['node status'])

# %%
#logistic
predictions_1 = logmodel.predict(df_xtst)
print(confusion_matrix(y_test,predictions_1))
print(classification_report(y_test,predictions_1))
# Out:
# [[157   1   1   6]
#  [ 13  43   0   0]
#  [  1   0  19  25]
#  [ 66   0   4  19]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.66      0.95      0.78       165
#    'No Block'       0.98      0.77      0.86        56
#         Block       0.79      0.42      0.55        45
#       NB-Wait       0.38      0.21      0.27        89
#
#   avg / total       0.66      0.67      0.64       355

# %%
#random forest
predictions_2 = rfc.predict(df_xtst)
print(confusion_matrix(y_test,predictions_2))
print(classification_report(y_test,predictions_2))
# Out:
# [[165   0   0   0]
#  [  0  56   0   0]
#  [  0   0  45   0]
#  [  0   0   0  89]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       1.00      1.00      1.00       165
#    'No Block'       1.00      1.00      1.00        56
#         Block       1.00      1.00      1.00        45
#       NB-Wait       1.00      1.00      1.00        89
#
#   avg / total       1.00      1.00      1.00       355

# %%
#lda
predictions_3 = lda.predict(df_xtst)
print(confusion_matrix(y_test,predictions_3))
print(classification_report(y_test,predictions_3))
# Out:
# [[137   3   2  23]
#  [  1  55   0   0]
#  [  0   0  31  14]
#  [ 45   0  11  33]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.75      0.83      0.79       165
#    'No Block'       0.95      0.98      0.96        56
#         Block       0.70      0.69      0.70        45
#       NB-Wait       0.47      0.37      0.42        89
#
#   avg / total       0.71      0.72      0.71       355

# %%
#qda
predictions_4 = qda.predict(df_xtst)
print(confusion_matrix(y_test,predictions_4))
print(classification_report(y_test,predictions_4))
# Out:
# [[  0 165   0   0]
#  [  0  56   0   0]
#  [  0  45   0   0]
#  [  0  89   0   0]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.00      0.00      0.00       165
#    'No Block'       0.16      1.00      0.27        56
#         Block       0.00      0.00      0.00        45
#       NB-Wait       0.00      0.00      0.00        89
#
#   avg / total       0.02      0.16      0.04       355
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:706: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:709: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#fine tuning and optimization

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
X = df_xtr.values
X = scale(X)
pca = PCA(n_components=13)
pca.fit(X)

#The amount of variance that each PC explains
var= pca.explained_variance_ratio_

#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print (var1)
# Out:
# [  53.28   86.65   93.52   97.99   99.5    99.75   99.95   99.99  100.
#   100.    100.    100.    100.  ]

# %%
plt.plot(var1)

# %%
#Looking at above plot I'm taking 6 variables
pca = PCA(n_components=6)
pca.fit(X)
X1=pca.fit_transform(X)

print(X1)
# Out:
# [[ 0.74331284 -1.21329468  0.20740507 -0.19829597 -0.29971321 -0.06870308]
#  [ 0.05809592  0.58263448 -1.39444674  0.19399918  0.15129035 -0.05625586]
#  [ 1.14341978  3.05472991 -1.71293272  0.11972144 -0.0518113   0.07304928]
#  ...,
#  [ 3.00752228  2.20997166 -0.01269086 -0.09270814  0.27244904  0.04721096]
#  [ 2.6385295   2.56800422 -1.41979532  0.14795713  0.35475549 -0.04167834]
#  [ 4.72315301  0.28253262  0.55227891 -0.08848686  0.73725327 -0.09578759]]

# %%
clf_5 = logmodel.fit(X1,y_train)
scores_5 = cross_val_score(clf_5, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_5.mean(), scores_9.std() * 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-2b042ea996c5> in <module>()
#       1 clf_5 = logmodel.fit(X1,y_train)
#       2 scores_5 = cross_val_score(clf_5, X1, y_train, cv=10)
# ----> 3 print("Accuracy: %0.2f (+/- %0.2f)" % (scores_5.mean(), scores_9.std() * 2))
#
# NameError: name 'scores_9' is not defined

# %%
clf_6 = rfc.fit(X1,y_train)
scores_6 = cross_val_score(clf_6, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_6.mean(), scores_6.std() * 2))
# Out:
# Accuracy: 0.99 (+/- 0.03)

# %%
clf_7 = qda.fit(X1,y_train)
scores_7 = cross_val_score(clf_7, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_7.mean(), scores_7.std() * 2))
# Out:
# Accuracy: 0.46 (+/- 0.04)

# %%
clf_8 = lda.fit(X1,y_train)
scores_8 = cross_val_score(clf_8, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_8.mean(), scores_8.std() * 2))
# Out:
# Accuracy: 0.65 (+/- 0.08)

# %%
X_t=X_test.drop(['node status', 'packet lost'], axis = 1).values
X_t = scale(X_t)
pca = PCA(n_components=13)
pca.fit(X)

#The amount of variance that each PC explains
vari= pca.explained_variance_ratio_

#Cumulative Variance explains
var2=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print (var2)
# Out:
# [  53.28   86.65   93.52   97.99   99.5    99.75   99.95   99.99  100.
#   100.    100.    100.    100.  ]

# %%
plt.plot(var2)

# %%
pca = PCA(n_components=6)
pca.fit(X_t)
X2=pca.fit_transform(X_t)

print(X2)
# Out:
# [[ 6.47989754 -1.35112371  4.85103032  1.99380277 -1.12562007 -1.16314025]
#  [ 1.09010202 -2.11729836 -1.60299616  0.72928604  0.07922464  0.12792209]
#  [ 1.10043169  0.11482952  0.15487516 -1.1300027   0.24243156  0.25866125]
#  ...,
#  [ 1.53982256  1.45410969 -0.68047143 -1.21157591  0.31062513 -0.06679012]
#  [-0.49193702  1.16839087 -0.01603195 -1.18382554  0.14012165  0.27785467]
#  [ 0.50657172  0.95469938 -0.62981795 -1.14846925  0.26900818 -0.17202291]]

# %%
predictions_8 = logmodel.predict(X2)
print(confusion_matrix(y_test,predictions_8))
print(classification_report(y_test,predictions_8))
# Out:
# [[76 13 14 62]
#  [ 3  0 12 41]
#  [37  6  2  0]
#  [66 16  0  7]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.42      0.46      0.44       165
#    'No Block'       0.00      0.00      0.00        56
#         Block       0.07      0.04      0.05        45
#       NB-Wait       0.06      0.08      0.07        89
#
#   avg / total       0.22      0.24      0.23       355

# %%
predictions_9 = qda.predict(X2)
print(confusion_matrix(y_test,predictions_9))
print(classification_report(y_test,predictions_9))
# Out:
# [[165   0   0   0]
#  [ 56   0   0   0]
#  [ 45   0   0   0]
#  [ 89   0   0   0]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.46      1.00      0.63       165
#    'No Block'       0.00      0.00      0.00        56
#         Block       0.00      0.00      0.00        45
#       NB-Wait       0.00      0.00      0.00        89
#
#   avg / total       0.22      0.46      0.29       355
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
predictions_10 = lda.predict(X2)
print(confusion_matrix(y_test,predictions_10))
print(classification_report(y_test,predictions_10))
# Out:
# [[79 12 21 53]
#  [ 3  0 25 28]
#  [31 13  0  1]
#  [65 15  2  7]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.44      0.48      0.46       165
#    'No Block'       0.00      0.00      0.00        56
#         Block       0.00      0.00      0.00        45
#       NB-Wait       0.08      0.08      0.08        89
#
#   avg / total       0.23      0.24      0.23       355

# %%
predictions_10 = rfc.predict(X2)
print(confusion_matrix(y_test,predictions_10))
print(classification_report(y_test,predictions_10))
# Out:
# [[121  10  28   6]
#  [ 33   0  16   7]
#  [ 34  10   1   0]
#  [ 75   8   2   4]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.46      0.73      0.57       165
#    'No Block'       0.00      0.00      0.00        56
#         Block       0.02      0.02      0.02        45
#       NB-Wait       0.24      0.04      0.08        89
#
#   avg / total       0.28      0.35      0.28       355

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
names = ['utilised BW Rate ', 'packet drop rate', 'full bandwidth', 'used BW',
       'lost BW', 'packet transmitted', 'packet received', 'packet lost',
       'transmitted byte', 'received byte', '10 run avg drop rate',
       '10 run avg BW', 'node status']

# %%
# feature selection using UNIVARIATE Selection
# feature extraction
test = SelectKBest(score_func=chi2, k=13)
fit = test.fit(df_xtr, y_train)
# summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)
# Out:
# [  2.601e+01   3.569e+01   7.226e+03   3.574e+04   1.550e+04   6.524e+05
#    3.193e+06   1.273e+06   9.395e+08   4.731e+09   2.752e+01   3.019e+01
#    9.198e+01]

# %%
print(features[0:5,:])
# Out:
# [[ 0.697 -0.699 -0.136  0.107 -0.446 -0.135  0.091 -0.45  -0.135  0.014
#   -0.478  0.744  0.015]
#  [-0.138  0.139  0.207  0.011  0.401  0.206 -0.005  0.394  0.206 -0.042
#    0.279 -0.309 -1.307]
#  [-0.486  0.486  1.234  0.488  1.715  1.234  0.47   1.716  1.234  0.232
#    0.39  -0.545 -1.307]
#  [ 1.631 -1.632  0.207  0.873 -0.987  0.206  0.852 -0.97   0.206  0.451
#   -1.552  1.692  0.015]
#  [ 0.505 -0.505 -0.821 -0.563 -0.755 -0.821 -0.577 -0.775 -0.821 -0.37
#   -0.631  0.603  0.015]]

# %%
df_xtr.columns
# Out:
# Index(['utilised BW Rate ', 'packet drop rate', 'full bandwidth', 'used BW',
#        'lost BW', 'packet transmitted', 'packet received', 'packet lost',
#        'transmitted byte', 'received byte', '10 run avg drop rate',
#        '10 run avg BW', 'node status'],
#       dtype='object')

# %%
df_chi = df_xtr.copy()
df_chit = df_xtst.copy()

# %%
df_chi.drop(['utilised BW Rate ', 'packet drop rate', 'full bandwidth', 'used BW',
       'lost BW', '10 run avg drop rate',
       '10 run avg BW', 'node status'], axis = 1, inplace = True)
df_chit.drop(['utilised BW Rate ', 'packet drop rate', 'full bandwidth', 'used BW',
       'lost BW', '10 run avg drop rate',
       '10 run avg BW', 'node status'], axis = 1, inplace = True)

# %%
clf1 = logmodel.fit(df_chi, y_train)
pred1 = logmodel.predict(df_chit)

print(confusion_matrix(y_test,pred1))
print(classification_report(y_test,pred1))
# Out:
# [[157   1   1   6]
#  [ 13  43   0   0]
#  [  1   0  19  25]
#  [ 66   0   4  19]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.66      0.95      0.78       165
#    'No Block'       0.98      0.77      0.86        56
#         Block       0.79      0.42      0.55        45
#       NB-Wait       0.38      0.21      0.27        89
#
#   avg / total       0.66      0.67      0.64       355

# %%
clf2 = rfc.fit(df_chi, y_train)
pred2 = rfc.predict(df_chit)

print(confusion_matrix(y_test,pred2))
print(classification_report(y_test,pred2))
# Out:
# [[164   0   0   1]
#  [  0  56   0   0]
#  [  5   0  40   0]
#  [  0   0   0  89]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.97      0.99      0.98       165
#    'No Block'       1.00      1.00      1.00        56
#         Block       1.00      0.89      0.94        45
#       NB-Wait       0.99      1.00      0.99        89
#
#   avg / total       0.98      0.98      0.98       355

# %%
clf3 = qda.fit(df_chi, y_train)
pred3 = qda.predict(df_chit)

print(confusion_matrix(y_test,pred3))
print(classification_report(y_test,pred3))
# Out:
# [[165   0   0   0]
#  [ 49   7   0   0]
#  [ 45   0   0   0]
#  [ 89   0   0   0]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.47      1.00      0.64       165
#    'No Block'       1.00      0.12      0.22        56
#         Block       0.00      0.00      0.00        45
#       NB-Wait       0.00      0.00      0.00        89
#
#   avg / total       0.38      0.48      0.33       355
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
clf4 = lda.fit(df_chi, y_train)
pred4 = lda.predict(df_chit)

print(confusion_matrix(y_test,pred4))
print(classification_report(y_test,pred4))
# Out:
# [[138  11   1  15]
#  [ 18  38   0   0]
#  [  0   0  16  29]
#  [ 52   0   9  28]]
#                precision    recall  f1-score   support
#
# 'NB-No Block'       0.66      0.84      0.74       165
#    'No Block'       0.78      0.68      0.72        56
#         Block       0.62      0.36      0.45        45
#       NB-Wait       0.39      0.31      0.35        89
#
#   avg / total       0.61      0.62      0.60       355
# C:\Users\SUVID ANAND\ANACONDA\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
